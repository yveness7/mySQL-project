# %% [markdown]
# # You've Been Warned! (Quest III)
# Author: Agata Płucienik & Ivet Petkova
#
# Date: 02/11/2023

# %% [markdown]
# ## Introduction

# %% [markdown]
# Welcome to ‘You’ve Been Warned!’. Our project has as it's main goal to analyze data retrieved from the IUCN Red List of Threatened Species and retreive insites based on clearly defined hypothesis.
#
# The objective of this preliminary analysis is to get a better understanding on the most threatened groups of species on our planet in terms of numbers based on the available data and by choosing two geographic areas of interest to us, Europe and South & South Eastern Asia, to find out which of the two areas has more threatened species, as well as in which country we could potential draft a conservation plan.

# %% [markdown]
# ## Data Acquisition and Preprocessing

# %% [markdown]
# The data that was used for out analysis is publicly accessible on this link https://www.iucnredlist.org/statistics in the form of CSVs.
#
#
# The objective for our effort is to analyse the data with the use of MySQL, Python and Pandas,and then visualise the results with Matplotlib and Tableau.
#
# An important aspect of our analysis that is worth mentioning is that during our analysis, we used 5 different datasets: the global distribution of threatened species, the distribution of threatened species in Europe by major group by country, the distribution of threatened species in South & South East Asia by major group by country, the threatened animal species in Europe and the ones in South East Asia.
#
# The data was already clean no with null or Nan values present, so we could start with the analysis quite straght forward.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Hereby you can see the EDA of our SQL Model:
#
# ![YOU%E2%80%99VE%20BEEN%20WARNED.jpg](attachment:YOU%E2%80%99VE%20BEEN%20WARNED.jpg)

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ![YOU%E2%80%99VE%20BEEN%20WARNED%281%29.jpg](attachment:YOU%E2%80%99VE%20BEEN%20WARNED%281%29.jpg)

# %% [markdown]
# ## Data Analysis

# %%
#In this section, perform the main analysis of your data.
#Include code and explanations for any statistical tests or machine learning models used.
#Interpret the results of your analysis and relate them to the project objectives.
#Use text to narrate the story of your data, connecting insights and conclusions logically.

# %% [markdown]
# ## Insights and Conclusions

# %% [markdown]
# After conducting our analysis, we found the answers to our two main objectives:
# 1. Mammals are not the most threatened group in the animal kingdom.
# 2. South and South East Asia has way more threatened species than Europe.

# %% [markdown]
# ## Recommendations and Conclusion

# %% [markdown]
# We recommend that thorought data analysis should always be conducted before a new conservation project is being crafted in order to make sure that we put equal and sensible amount of effort in protecting a diverse range of species on pur planet. Attention should be put not only on the biggest, most visible and pleasing to the eye animals, but there should be a deeper understanding and wholistic view of the role that different species play in maintaining their enviroment and evolutionary success. Coorepation and open sharing of data and insights is the key to successful conservation efforts.
